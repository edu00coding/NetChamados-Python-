# %%
import time
import os
import random
from IPython.display import clear_output


print("======================== Bem Vindos ao Suporte da Netsuporte ===================\n")
print("\t\t\tSuporte Técnico e Desenvolvimento\n")
print("\tAtuando na resolução de problemas técnicos de software e hardware\n")
print("\t=================================================================\n")
# Out:
# ======================== Bem Vindos ao Suporte da Netsuporte ===================
#
# 			Suporte Técnico e Desenvolvimento
#
# 	Atuando na resolução de problemas técnicos de software e hardware
#
# ...

# %%
  print("\t\tApresento para você nossas opções para abertura de chamados:\n")
  print("\tOpção 0 : encerrando o sistema\n")
  print("\tOpção 1 : para abertura de chamado com o nossos técnicos\n")
  print("\tOpção 2 : para falar com o nosso financeiro\n")
  print("\tOpção 3 : para falar com o nosso comercial\n")


escolha = input("\tPreciso que você escolha uma dessas opções para darmos continuidade no atendimento\n")

if escolha == "Opção 1" or escolha == "1":
    print("\tOk estou te tranferindo para o suporte técnico\n")


    for i in range (3):
      time.sleep(1)
      print("\tCarregando ...\n")
# Out:
# 		Apresento para você nossas opções para abertura de chamados:
#
# 	Opção 0 : encerrando o sistema
#
# 	Opção 1 : para abertura de chamado com o nossos técnicos
#
# 	Opção 2 : para falar com o nosso financeiro
#
# 	Opção 3 : para falar com o nosso comercial

# %%
print("\tBem Vindo a central da área técnica é muito bom ter você conosco\n")
print("\tEm que podemos te ajudar?\n")
print("\tOpção 1 : Agendamento de visita técnica\n")
print("\tOpção 2 : Preciso de uma ajuda remotamente\n")
print("\tOpção 3 : Preciso fazer uma solicitação de cartucho de toner\n")
escolha = input("\t\tDigite a opção que precisa : \n")

# %%
if escolha == "Opção 1" or "1":
  print("\tOk, iremos fazer o agendamento da visita técnica para você, mas antes eu preciso que voce descreva em algumas palavras o que esta acontecendo com a sua impressora ou computador. Conta para mim em poucas palavras.\n")
  depoimento = str(input("\t\t"))
  print("\tOK, estou anexando isso ao chamado\n")
  numero_do_chamado = random.randint(100,9999)
  print(f"\tAqui esta o numero de seu chamado {numero_do_chamado}\n")
  print("\tMuito obrigado por confiar na NetSuporte\n")

elif escolha == "Opção 2" or escolha  == "2":
  print("Testando")
